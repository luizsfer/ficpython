# %% [markdown]
# #  Introdução ao Python
# ## Professor: Luiz Ferreira

# %% [markdown]
# ## Módulo 2
#
# ### Python para Web

# %% [markdown]
# _____________

# %% [markdown]
# ## Conceito de Web

# %% [markdown]
# Conforme conhecemos, a internet foi um movimento emcabeçada pelo físico Tim Berners-Lee, em 1991, que criou o nosso conhecido termo WWW (World Wide Web), que foi responsável pela explosão da tecnologia pelo mundo todo, encurtando distâncias e aumentando o acesso a conhecimentos até então restritos a poucos.
#
# No dia 11 de setembro de 2018, até as 11:30 da manhã, o número de sites criados ultrapassava 1.911.282.932, segundo estimativas do site http://www.internetlivestats.com/total-number-of-websites/.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# O poder da web é conhecido de muitos, porém, nem todos ainda possuem acesso a tal, dados do site https://www.internetworldstats.com/stats.htm, mostram a quantidade de usuários e a penetração do uso de internet por região do globo.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Python para Web

# %% [markdown]
# Assim como vimos em interfaces gráficas, existe uma gama de recursos para se trabalhar programação Web utilizando Python. Podemos citar:
#
# - Django
# - Flask
# - web2py
# - BlueBream
# - Tornado
#
# Os chamados Frameworks possuem características próprias e sua escolha depende do objetivo, conhecimento e interesse do programador, uma vez que ambas possuem a mesma base e o mesmo objetivo final.

# %% [markdown]
# ## Django

# %% [markdown]
# Django é uma alternativa viável para todo tipo de projeto em web. Possui uma flexibilidade desejável quanto ao uso de seus recursos, uma comunidade muito ativa e integrada e uma curva de aprendizado relativamente pequena.

# %% [markdown]
# Uma de suas principais características é a emulação de um micro-servidor web, que será muito útil, principalmente, no ambiente de desenvolvimento, ou seja, não é necessário a instalação de um servidor Apache com PHP para o desenvolvimento de um sistema robusto.

# %% [markdown]
# Para obtermos o framework Django, temos o seguinte comando:

# %%
pip install django

# %% [markdown]
# #### Todo o material dessa aula é uma adaptação da Documentação oficial do framework Django

# %% [markdown]
# Para verificarmos a instalação do Django, bem como sua versão, utilizamos o comando:

# %%
python -m django --version

# %% [markdown]
# ## Primeiro projeto

# %% [markdown]
# Com o django instalado, passamos para a criação do projeto web.
#
# Nessa fase você terá que preocupar-se com algumas configurações iniciais. Isto é, você precisará auto-gerar um código para iniciar um projeto Django – uma coleção de configurações para uma instância do Django, incluindo configuração do banco de dados, opções específicas do Django e configurações específicas da aplicação.
#
# Sabendo disso, acessemos via terminal ou prompt de comando, a pasta onde nosso projeto ficará armazenado e então executemos o seguinte comando:

# %%
django-admin startproject mysite

# %% [markdown]
# Este comando criará um novo projeto com o nome `mysite`, dentro da pasta em que estamos utilizando. O comando criou uma estrutura de pastas e arquivos, a saber:

# %%
mysite/
    manage.py
    mysite/
        __init__.py
        settings.py
        urls.py
        wsgi.py

# %% [markdown]
# Para entendermos o que cada um significa, observemos:

# %% [markdown]
# - O arquivo mysite/ exterior é apenas um contêiner para o seu projeto. Seu nome não importa para Django; você pode renomeá-lo para qualquer nome que você quiser.
# - manage.py: Um utilitário de linha de comando que permite a você interagir com esse projeto Django de várias maneiras. Você pode ler todos os detalhes sobre o manage.py em django-admin and manage.py.
# - O arquivo mysite/ interior é o pacote Python para o seu projeto. Seu nome é o nome do pacote Python que você vai precisar usar para importar coisas do seu interior (por exemplo, mysite.urls).
# - mysite/__init__.py: Um arquivo vazio que diz ao Python que este diretório deve ser considerado um pacote Python. Se você é um iniciante Python, leia mais sobre pacotes na documentação oficial do Python.
# - mysite/settings.py: Configurações para este projeto Django. Configurações do Django Irá revelar para você tudo sobre o funcionamento do settings.
# - mysite/urls.py: As declarações de URLs para este projeto Django; um “índice” de seu site movido a Django. Você pode ler mais sobre URLs em Despachante de URL.
# - mysite/wsgi.py: Um ponto de integração para servidores WEB compatíveis com WSGI usado para servir seu projeto. Veja Como implementar com WSGI para mais detalhes.

# %% [markdown]
# Apenas com essa estrutura inicial, temos uma página criada, para vermos o conteúdo, será necessário a execução do nosso servidor web de teste, para isso, utilizaremos o terminal ou prompt de comando:

# %%
python manage.py runserver

# %% [markdown]
# Se tudo estiver ok, você vera a seguinte saída na sua linha de comando:

# %%
Performing system checks...

System check identified no issues (0 silenced).

You have unapplied migrations; your app may not work properly until they are applied.
Run 'python manage.py migrate' to apply them.

agosto 01, 2018 - 15:50:53
Django version 2.0, using settings 'mysite.settings'
Starting development server at http://127.0.0.1:8000/
Quit the server with CONTROL-C.

# %% [markdown]
# Agora é uma boa hora para notar: não use esse servidor em nada relacionado a um ambiente de produção. Seu objetivo é ser utilizado apenas durante o desenvolvimento. (Nós estamos na atividade de criação de frameworks Web, não de servidores Web.)

# %% [markdown]
# Para acessar a página criada, devemos acessar o endereço indicado na linha de comando acima. No caso, http://127.0.0.1:8000/.
